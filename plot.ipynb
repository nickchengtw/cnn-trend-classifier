# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from src.preprocess.make_dataset import make_labeled_data
from src.utils.plot import *

df = pd.read_csv('data/raw/2330_stock_data_from_2016.csv', parse_dates=['Date'])
plot_closing_price(df, pd.to_datetime('2016-01-01'), pd.to_datetime('2016-06-01'))

# %%
df = pd.read_csv('./data/raw/2330_stock_data_from_2016.csv', parse_dates=['Date'])
df = df[(df['Date'] >= pd.to_datetime('2016-01-01')) & (df['Date'] <= pd.to_datetime('2016-06-01'))]
labels_df = pd.read_csv('./data/label/labels.csv')

df = make_labeled_data(df, labels_df)
# Out:
# c:\Users\nick\OneDrive\cnn-trend-classifier\src\preprocess\make_dataset.py:60: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'UP' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Date'] >= start_date) & (df['Date'] <= end_date), 'UpTrend'] = label
# c:\Users\nick\OneDrive\cnn-trend-classifier\src\preprocess\make_dataset.py:63: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'DOWN' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Date'] >= start_date) & (df['Date'] <= end_date), 'DownTrend'] = label

# %%
df = pd.read_csv('data/data_test.csv', parse_dates=['Date'], index_col=0, dtype={'Up Trend': 'object', 'Down Trend': 'object'})
plot_labeled(df)
# df.info()
