# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

from src.preprocess.make_dataset import make_labeled_data, read_label_studio_json
from src.utils.plot import *

# %%
labels = read_label_studio_json('data/label/labels.json')
df = pd.read_csv('./data/raw/2330_stock_data_from_2016.csv', parse_dates=['Date'])

dataset = make_labeled_data(df, labels)
dataset.head(20)
# Out:
# d:\cnn-trend-classifier\src\preprocess\make_dataset.py:60: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'UP' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Date'] >= start_date) & (df['Date'] <= end_date), 'UpTrend'] = label
# d:\cnn-trend-classifier\src\preprocess\make_dataset.py:63: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'DOWN' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Date'] >= start_date) & (df['Date'] <= end_date), 'DownTrend'] = label
#          Date   Open   High    Low  Close UpTrend DownTrend
# 0  2016-01-04  142.5  143.5  139.0  139.5     NaN       NaN
# 1  2016-01-05  139.0  140.0  137.0  138.0     NaN       NaN
# 2  2016-01-06  138.0  138.0  135.0  135.5     NaN       NaN
# ...

# %%
dataset.to_csv('data.csv')
